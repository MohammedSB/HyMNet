# %%
# %run C:/Users/MohammedSB/Desktop/projects/Utils/Blacksmith.ipynb
# %run C:/Users/MohammedSB/Desktop/projects/Hypertension/Datasets.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\execution.py in run(self, parameter_s, runner, file_finder)
#     702             fpath = arg_lst[0]
# --> 703             filename = file_finder(fpath)
#     704         except IndexError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\utils\path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'C:/Users/MohammedSB/Desktop/projects//Requirements.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# C:/Users/MohammedSB/Desktop/projects/Hypertension/Datasets.ipynb in <module>
# ...
