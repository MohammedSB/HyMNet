# %%
# Image focus
mlp = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=32, out_features=16),
)

cnn = get_densenet201(device=device, freeze=True, with_mlp=True, outputs=128)

fm = nn.Sequential(
    nn.Linear(in_features=144, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=256, out_features=64),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=64, out_features=16),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=16, out_features=1),
)

mlp, cnn, fm = mlp.to(device).float(), cnn.to(device).float(), fm.to(device).float()

Validation Set:
Average Loss:  0.541308,    Accuracy: 70.31%,    Correct Counter: 161/229,    F1 Score: 0.73,    Precision: 0.65,    Recall:  0.82

# %%
# Deeper
mlp = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=32, out_features=16),
)

cnn = get_densenet201(device=device, freeze=True, with_mlp=True, outputs=128)

fm = nn.Sequential(
    nn.Linear(in_features=144, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=256, out_features=512),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=512, out_features=128),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=128, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=32, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=8, out_features=1),
)

mlp, cnn, fm = mlp.to(device).float(), cnn.to(device).float(), fm.to(device).float()

Validation Set:
Average Loss:  0.524801,    Accuracy: 72.93%,    Correct Counter: 167/229,    F1 Score: 0.77,    Precision: 0.65,    Recall:  0.94

# %%
# Even Deeper
mlp = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=32, out_features=16),
)

cnn = get_densenet201(device=device, freeze=True, with_mlp=True, outputs=128)

fm = nn.Sequential(
    nn.Linear(in_features=144, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=256, out_features=512),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=512, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=256, out_features=128),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=128, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=32, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=8, out_features=1),
)

mlp, cnn, fm = mlp.to(device).float(), cnn.to(device).float(), fm.to(device).float()


Validation Set:
    Average Loss:  0.540165,    Accuracy: 73.80%,    Correct Counter: 169/229,    F1 Score: 0.77,    Precision: 0.66,    Recall:  0.93

# %%
# above + no mlp

Validation Set:
    Average Loss:  0.539118,    Accuracy: 72.93%,    Correct Counter: 167/229,    F1 Score: 0.78,    Precision: 0.65,    Recall:  0.96

# %%
mlp = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=32, out_features=64),
)

cnn = get_densenet201(device=device, freeze=True, with_mlp=False, outputs=64)

fm = nn.Sequential(
    nn.Linear(in_features=128, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=256, out_features=512),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=512, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=256, out_features=128),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=128, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=32, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=8, out_features=1),
)

mlp, cnn, fm = mlp.to(device).float(), cnn.to(device).float(), fm.to(device).float()

Validation Set:
    Average Loss:  0.528693,    Accuracy: 73.80%,    Correct Counter: 169/229,    F1 Score: 0.78,    Precision: 0.66,    Recall:  0.95

# %%
mlp = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=32, out_features=64),
)

cnn = get_densenet201(device=device, freeze=True, with_mlp=False, outputs=64)

fm = nn.Sequential(
    nn.Linear(in_features=128, out_features=256),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=256, out_features=512),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=512, out_features=128),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=128, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=32, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=8, out_features=1),
)

mlp, cnn, fm = mlp.to(device).float(), cnn.to(device).float(), fm.to(device).float()


Validation Set:
    Average Loss:  0.539588,    Accuracy: 72.05%,    Correct Counter: 165/229,    F1 Score: 0.77,    Precision: 0.64,    Recall:  0.95

# %%
# Late fusion lr 1e-3

mlp = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=32, out_features=16),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=16, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=1),
)

cnn = get_densenet201(device=device, freeze=True, with_mlp=True, outputs=1)

fm = nn.Sequential(
    nn.Linear(in_features=2, out_features=8),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=8, out_features=16),
    nn.LeakyReLU(inplace=True),
    nn.Linear(in_features=16, out_features=32),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=32, out_features=16),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=16, out_features=4),
    nn.LeakyReLU(inplace=True),
    nn.Dropout(),
    nn.Linear(in_features=4, out_features=1),
)

mlp, cnn, fm = mlp.to(device).float(), cnn.to(device).float(), fm.to(device).float()

#Validation Set:
#    Average Loss:  0.534475,    Accuracy: 72.05%,    Correct Counter: 165/229,    F1 Score: 0.77,    Precision: 0.64,    Recall:  0.95
